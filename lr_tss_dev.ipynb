# %%
import pandas as pd
import pdb
import numpy as np
import itertools
from utils import *
from snakemake.io import expand
import yaml
import cerberus

# %%
config_file = 'workflow/config.yml'
with open(config_file) as f:
    config = yaml.safe_load(f)

# %%
species = 'human'
ca_h5 = 'workflow/'+expand(config['lr']['ca'], species=species)[0]
meta_file = 'workflow/'+expand(config['lr']['meta'], species=species)[0]
encode_meta_file = 'workflow/'+expand(config['lr']['encode_meta'], species=species)[0]
filt_ab = 'workflow/'+expand(config['lr']['filt_ab'], species=species)[0]

# %%
min_tpm = 1

# %%
# get dataset<->experiment<->encode biosample shorthand

meta = pd.read_csv(meta_file, sep='\t')
meta = meta[['ENCODE_experiment_id', 'dataset']].rename({'ENCODE_experiment_id': 'Experiment accession'}, axis=1)

enc_meta = process_encode_metadata(encode_meta_file)
enc_meta = enc_meta[['Experiment accession', 'biosamp', 'biorep']].drop_duplicates()

meta = meta.merge(enc_meta, how='left', on='Experiment accession')
meta = meta[['dataset', 'biosamp', 'biorep']]
meta.set_index('dataset', inplace=True)

# %%
df = pd.read_csv(filt_ab, sep='\t')
df = add_feat(df,
              'annot_transcript_id', 
              kind='tss', 
              as_index=True)

# %%
drop_cols = ['gene_ID', 'transcript_ID',
             'annot_gene_id', 'annot_transcript_id',
             'annot_gene_name', 'annot_transcript_name',
             'n_exons', 'length', 'gene_novelty',
             'transcript_novelty', 'ISM_subtype']
df.drop(drop_cols, axis=1, inplace=True)

# %%
df = df.reset_index()
df = df.groupby('tss').sum()

# %%
df.head()
# Out:
#                    h9_neural_crest_1_1  a673_1_1  h9_chondro_1_3  \
# tss
# ENSG00000000003_1                  265       119              40
# ENSG00000000003_2                    0         0               0
# ENSG00000000005_2                    0         0               0
# ENSG00000000005_3                    0         0               0
# ENSG00000000419_1                   57        57              13
#
#                    hl60_m2_24hr_1_2  h9_neural_crest_1_2  cardiac_septum_1_1  \
# tss
# ENSG00000000003_1                 0                  322                   4
# ENSG00000000003_2                 0                    0                   0
# ENSG00000000005_2                 0                    0                   0
# ENSG00000000005_3                 0                    0                   1
# ENSG00000000419_1                72                  102                  23
#
#                    h9_panc_progen_1_2  lower_lobe_of_left_lung_2_1  \
# tss
# ENSG00000000003_1                1269                           28
# ENSG00000000003_2                   0                            0
# ENSG00000000005_2                   0                            0
# ENSG00000000005_3                   0                            0
# ENSG00000000419_1                  56                            4
#
#                    h9_panc_beta_1_1  huvec_1_2  ...  right_cardiac_atrium_2_1  \
# tss                                             ...
# ENSG00000000003_1               603        162  ...                        10
# ENSG00000000003_2                 1          0  ...                         0
# ENSG00000000005_2                 0          0  ...                         0
# ENSG00000000005_3                 6          0  ...                         0
# ENSG00000000419_1                98         73  ...                        12
#
#                    right_ventricle_myocardium_superior_1_1  pc9_1_1  h9_1_2  \
# tss
# ENSG00000000003_1                                       15      197     569
# ENSG00000000003_2                                        0        0       0
# ENSG00000000005_2                                        0        0       0
# ENSG00000000005_3                                        0        0       0
# ENSG00000000419_1                                       19       78     134
#
#                    pgp1_endo_1_1  k562_2_1  ovary_1_1  hl60_m1_72hr_1_1  \
# tss
# ENSG00000000003_1             79         1        330                 0
# ENSG00000000003_2              0         0          0                 0
# ENSG00000000005_2              0         0          0                 0
# ENSG00000000005_3              0         0          0                 0
# ENSG00000000419_1             30        72         19                25
#
#                    k562_3_2  posterior_vena_cava_2_1
# tss
# ENSG00000000003_1         0                        6
# ENSG00000000003_2         0                        0
# ENSG00000000005_2         0                        0
# ENSG00000000005_3         0                        0
# ENSG00000000419_1        43                        6
#
# [5 rows x 138 columns]

# %%
df = df.transpose()
df['total'] = df.sum(axis=1)

# %%
df = df.divide(df.total, axis=0)*1e6

# %%
df.drop('total', axis=1, inplace=True)

# %%
df = df>=min_tpm

# %%
df.head()
# Out:
# tss                  ENSG00000000003_1  ENSG00000000003_2  ENSG00000000005_2  \
# h9_neural_crest_1_1               True              False              False
# a673_1_1                          True              False              False
# h9_chondro_1_3                    True              False              False
# hl60_m2_24hr_1_2                 False              False              False
# h9_neural_crest_1_2               True              False              False
#
# tss                  ENSG00000000005_3  ENSG00000000419_1  ENSG00000000419_8  \
# h9_neural_crest_1_1              False               True              False
# a673_1_1                         False               True              False
# h9_chondro_1_3                   False               True              False
# hl60_m2_24hr_1_2                 False               True              False
# h9_neural_crest_1_2              False               True              False
#
# tss                  ENSG00000000457_1  ENSG00000000457_2  ENSG00000000457_3  \
# h9_neural_crest_1_1               True              False              False
# a673_1_1                          True              False              False
# h9_chondro_1_3                    True              False              False
# hl60_m2_24hr_1_2                 False              False              False
# h9_neural_crest_1_2               True              False               True
#
# tss                  ENSG00000000460_1  ...  ENSG00000285972_1  \
# h9_neural_crest_1_1               True  ...              False
# a673_1_1                          True  ...              False
# h9_chondro_1_3                    True  ...              False
# hl60_m2_24hr_1_2                 False  ...              False
# h9_neural_crest_1_2               True  ...              False
#
# tss                  ENSG00000285976_1  ENSG00000285976_2  ENSG00000285978_1  \
# h9_neural_crest_1_1               True               True              False
# a673_1_1                          True               True              False
# h9_chondro_1_3                    True               True              False
# hl60_m2_24hr_1_2                  True               True              False
# h9_neural_crest_1_2               True               True              False
#
# tss                  ENSG00000285980_2  ENSG00000285988_1  ENSG00000285988_2  \
# h9_neural_crest_1_1              False              False              False
# a673_1_1                         False              False              False
# h9_chondro_1_3                   False              False              False
# hl60_m2_24hr_1_2                 False              False              False
# h9_neural_crest_1_2              False              False              False
#
# tss                  ENSG00000285988_3  ENSG00000285988_4  ENSG00000285991_1
# h9_neural_crest_1_1              False              False              False
# a673_1_1                         False              False               True
# h9_chondro_1_3                   False              False              False
# hl60_m2_24hr_1_2                 False              False              False
# h9_neural_crest_1_2              False              False              False
#
# [5 rows x 76487 columns]

# %%
# add metadata so we can merge on biosample as dictated by encode
df = df.merge(meta, how='left', left_index=True, right_index=True)

# %%
df.reset_index(drop=True, inplace=True)
df = df.groupby(['biosamp', 'biorep']).max()

# %%
df.head()
# Out:
#                       ENSG00000000003_1  ENSG00000000003_2  ENSG00000000005_2  \
# biosamp       biorep
# a673          1                    True              False              False
# adrenal_gland 1                    True              False              False
#               2                    True              False              False
#               3                    True              False              False
# aorta         1                    True              False              False
#
#                       ENSG00000000005_3  ENSG00000000419_1  ENSG00000000419_8  \
# biosamp       biorep
# a673          1                   False               True              False
# adrenal_gland 1                   False               True              False
#               2                   False               True              False
#               3                   False               True              False
# aorta         1                   False               True              False
#
#                       ENSG00000000457_1  ENSG00000000457_2  ENSG00000000457_3  \
# biosamp       biorep
# a673          1                    True              False              False
# adrenal_gland 1                    True              False              False
#               2                    True              False              False
#               3                    True              False              False
# aorta         1                    True              False              False
#
#                       ENSG00000000460_1  ...  ENSG00000285972_1  \
# biosamp       biorep                     ...
# a673          1                    True  ...              False
# adrenal_gland 1                   False  ...              False
#               2                   False  ...              False
#               3                   False  ...              False
# aorta         1                   False  ...              False
#
#                       ENSG00000285976_1  ENSG00000285976_2  ENSG00000285978_1  \
# biosamp       biorep
# a673          1                    True               True              False
# adrenal_gland 1                    True               True              False
#               2                   False               True              False
#               3                   False               True              False
# aorta         1                   False               True              False
#
#                       ENSG00000285980_2  ENSG00000285988_1  ENSG00000285988_2  \
# biosamp       biorep
# a673          1                   False              False              False
# adrenal_gland 1                   False              False              False
#               2                   False              False              False
#               3                   False              False              False
# aorta         1                   False              False              False
#
#                       ENSG00000285988_3  ENSG00000285988_4  ENSG00000285991_1
# biosamp       biorep
# a673          1                   False              False               True
# adrenal_gland 1                   False              False              False
#               2                   False              False              False
#               3                   False              False              False
# aorta         1                   False              False              False
#
# [5 rows x 76487 columns]

# %%
ca = cerberus.read(ca_h5)
tss = ca.tss.copy(deep=True)

# %%
tss.head()
# Out:
#   Chromosome      Start        End Strand               Name  \
# 0       chr1  169794989  169795129      +  ENSG00000000460_1
# 1       chr1  169795358  169795459      +  ENSG00000000460_2
# 2       chr1  169794679  169794780      +  ENSG00000000460_3
# 3       chr1  169795870  169795971      +  ENSG00000000460_4
# 4       chr1  169661956  169662057      +  ENSG00000000460_5
#
#                                               source novelty          gene_id  \
# 0  v40,v29,lapa,gtex,encode_cage,fantom_cage,enco...   Known  ENSG00000000460
# 1                                   v40,v29,lapa,pls   Known  ENSG00000000460
# 2                              v40,v29,lapa,gtex,pls   Known  ENSG00000000460
# 3                                        v40,v29,pls   Known  ENSG00000000460
# 4                                       v40,v29,dels   Known  ENSG00000000460
#
#    tss
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
